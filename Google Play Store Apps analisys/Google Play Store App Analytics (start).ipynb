# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.sample(5) # Show 5 random rows from the dataframe
# Out:
#                                              App           Category  Rating  \
# 956                                  Dt Tracking  AUTO_AND_VEHICLES    4.00
# 10451                 LINE Camera - Photo editor        PHOTOGRAPHY    4.30
# 4445   U Assist - Screen Mirroring & Sharing App       PRODUCTIVITY    4.00
# 8285                           Bejeweled Classic             FAMILY    4.40
# 1537                          EP Search and Find             FAMILY     NaN
#
#        Reviews  Size_MBs     Installs  Type Price Content_Rating  \
# 956          4     24.00          100  Free     0       Everyone
# 10451  1517369      6.90  100,000,000  Free     0       Everyone
# 4445       198      3.50       50,000  Free     0       Everyone
# 8285    203101     19.00    5,000,000  Free     0       Everyone
# 1537        20     23.00          500  Free     0       Everyone
#
#                 Genres      Last_Updated         Android_Ver
# ...

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
# delete last two column
df_apps.drop(df_apps[['Last_Updated', 'Android_Ver']], axis=1, inplace=True)

# %%
df_apps.sample(10)
# Out:
#                                                     App             Category  \
# 2749                     Free Resume Builder – CV Maker             BUSINESS
# 5722                                          e-Anatomy              MEDICAL
# 4528                                 Quiz TRUE or FALSE                 GAME
# 4209                                             N-Back               FAMILY
# 7856                              I'm Ping Pong King :)               SPORTS
# 6247  Destiny Ninja Shall we date otome games love s...                 GAME
# 560                                        FoothillsVet              MEDICAL
# 2949                       AW Tozer Devotionals - Daily  BOOKS_AND_REFERENCE
# 8601                               Microsoft Translator         PRODUCTIVITY
# 7858                                        MK eCatalog            LIFESTYLE
#
#       Rating  Reviews  Size_MBs   Installs  Type Price Content_Rating  \
# ...

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps['Rating'].isna().sum()
# Out:
# 1474

# %%
df_apps_clean = df_apps.dropna()
print(df_apps_clean.shape)
df_apps_clean.head()
# Out:
# (9367, 10)
#                                                 App Category  Rating  Reviews  \
# 21                              KBA-EZ Health Guide  MEDICAL    5.00        4
# 28                                         Ra Ga Ba     GAME    5.00        2
# 47                                          Mu.F.O.     GAME    5.00        2
# 82                                 Brick Breaker BR     GAME    5.00        7
# 99  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00        1
#
#     Size_MBs Installs  Type  Price Content_Rating   Genres
# 21     25.00        1  Free      0       Everyone  Medical
# 28     20.00        1  Paid  $1.49       Everyone   Arcade
# 47     16.00        1  Paid  $0.99       Everyone   Arcade
# 82     19.00        5  Free      0       Everyone   Arcade
# 99      4.60        5  Free      0       Everyone  Medical

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
df_apps_clean.duplicated(subset='App').sum()
# Out:
# 1170

# %%
# how many times "Instagram" is in the dataframe?
df_apps_clean['App'].value_counts()['Instagram']
# Out:
# 4

# %%
df_apps_clean.drop_duplicates(subset='App', inplace=True)
df_apps_clean.shape
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_16992\3944328078.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (8197, 10)

# %%
# again, how many times "Instagram" is in the dataframe? should be 1
df_apps_clean['App'].value_counts()['Instagram']
# Out:
# 1

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_clean.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres'],
#       dtype='object')

# %%
df_apps_clean.Size_MBs.max()
# Out:
# 100.0

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_clean.sort_values('Size_MBs', ascending=False).head()
# Out:
#                                   App            Category  Rating  Reviews  \
# 9942   Talking Babsy Baby: Baby Games           LIFESTYLE    4.00   140995
# 10687          Hungry Shark Evolution                GAME    4.50  6074334
# 9943            Miami crime simulator                GAME    4.00   254518
# 9944     Gangster Town: Vice District              FAMILY    4.30    65146
# 3144                       Vi Trainer  HEALTH_AND_FITNESS    3.60      124
#
#        Size_MBs     Installs  Type Price Content_Rating  \
# 9942     100.00   10,000,000  Free     0       Everyone
# 10687    100.00  100,000,000  Free     0           Teen
# 9943     100.00   10,000,000  Free     0     Mature 17+
# 9944     100.00   10,000,000  Free     0     Mature 17+
# 3144     100.00        5,000  Free     0       Everyone
#
#                        Genres
# 9942   Lifestyle;Pretend Play
# 10687                  Arcade
# 9943                   Action
# 9944               Simulation
# ...

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_clean.sort_values('Reviews', ascending=False).head()
# Out:
#                                             App       Category  Rating  \
# 10805                                  Facebook         SOCIAL    4.10
# 10785                        WhatsApp Messenger  COMMUNICATION    4.40
# 10806                                 Instagram         SOCIAL    4.50
# 10784  Messenger – Text and Video Chat for Free  COMMUNICATION    4.00
# 10650                            Clash of Clans           GAME    4.60
#
#         Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805  78158306      5.30  1,000,000,000  Free     0           Teen
# 10785  69119316      3.50  1,000,000,000  Free     0       Everyone
# 10806  66577313      5.30  1,000,000,000  Free     0           Teen
# 10784  56642847      3.50  1,000,000,000  Free     0       Everyone
# 10650  44891723     98.00    100,000,000  Free     0   Everyone 10+
#
#               Genres
# 10805         Social
# 10785  Communication
# 10806         Social
# 10784  Communication
# ...

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings = df_apps_clean.Content_Rating.value_counts()

# %%
# pie chart of ratings
fig = px.pie(ratings, values=ratings, names=ratings.index, title='Content Ratings', hole=0.6)
fig.update_traces(textposition='inside', textinfo='percent', textfont_size=14)
fig.show()

# %%
# pie chart of "Reviews" column in the dataframe
fig = px.pie(df_apps_clean, values='Reviews', names='Category', title='Reviews by Category', hole=0.6)
fig.update_traces(textposition='inside', textinfo='percent', textfont_size=14)
fig.show()

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
print(df_apps_clean.Installs.describe())
print(df_apps_clean.info())
df_apps_clean.Installs.value_counts(ascending=False)
# Out:
# count          8197
# unique           19
# top       1,000,000
# freq           1417
# Name: Installs, dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8197 entries, 21 to 10835
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8197 non-null   object
#  1   Category        8197 non-null   object
#  2   Rating          8197 non-null   float64
#  3   Reviews         8197 non-null   int64
#  4   Size_MBs        8197 non-null   float64
#  5   Installs        8197 non-null   object
#  6   Type            8197 non-null   object
#  7   Price           8197 non-null   object
#  8   Content_Rating  8197 non-null   object
#  9   Genres          8197 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 704.4+ KB
# None
# 1,000,000        1417
# 100,000          1095
# 10,000            988
# 10,000,000        933
# 1,000             698
# ...

# %%
# convert the "Installs" column to numeric
df_apps_clean.Installs = df_apps_clean.Installs.str.replace(',', '').astype(int) # remove commas and convert to int
df_apps_clean[['Installs', 'App']].groupby('Installs').count()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_16992\4082074622.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         698
# 5000         425
# 10000        988
# 50000        457
# 100000      1095
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# 50000000     202
# 100000000    188
# 500000000     24
# 1000000000    20

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_clean.Price = df_apps_clean.Price.str.replace('$', '').astype(float)
df_apps_clean[['Price', 'App']].groupby('Price').count()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_16992\758434943.py:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# C:\Users\andre\AppData\Local\Temp\ipykernel_16992\758434943.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          App
# Price
# 0.00    7593
# 0.99     104
# 1.00       2
# 1.20       1
# 1.29       1
# ...      ...
# 299.99     1
# 379.99     1
# 389.99     1
# 399.99    11
# 400.00     1
#
# [73 rows x 1 columns]

# %%
# show the total number of the apps that costs more than $250
df_apps_clean[df_apps_clean.Price >= 250].shape
# Out:
# (15, 10)

# %%
# delete the apps that costs more than $250
df_apps_clean = df_apps_clean[df_apps_clean.Price < 250]

# %% [markdown]
# ### The most expensive apps sub $250

# %%
df_apps_clean[['Price', 'App']].sort_values('Price', ascending=False).head(20)
# Out:
#       Price                                                App
# 2281  79.99                          Vargo Anesthesia Mega App
# 1407  39.99                                       LTC AS Legal
# 2629  37.99                                   I am Rich Person
# 2481  33.99                            A Manual of Acupuncture
# 504   29.99                          AP Art History Flashcards
# 2463  29.99                                 PTA Content Master
# 2207  29.99                                           EMT PASS
# 4264  29.99                            Golfshot Plus: Golf GPS
# 4772  24.99   Human Anatomy Atlas 2018: Complete 3D Human Body
# 3241  24.99  Muscle Premium - Human Anatomy, Kinesiology, B...
# 2293  19.99                               Hospitalist Handbook
# 4470  19.99                                  DRAGON QUEST VIII
# 526   19.99                         USMLE Step 2 CK Flashcards
# 2119  19.99                                         NewTek NDI
# ...

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
# create a new column called "Highest grossing app" and show the top 10 apps 
df_apps_clean['Total_grossing'] = df_apps_clean['Installs'].mul(df_apps_clean['Price'])
df_apps_clean[['App', 'Total_grossing']].sort_values('Total_grossing', ascending=False).head(10)
# Out:
#                                 App  Total_grossing
# 9220                      Minecraft   69,900,000.00
# 8825                  Hitman Sniper    9,900,000.00
# 7151  Grand Theft Auto: San Andreas    6,990,000.00
# 7477            Facetune - For Free    5,990,000.00
# 7977        Sleep as Android Unlock    5,990,000.00
# 6594            DraStic DS Emulator    4,990,000.00
# 6082                   Weather Live    2,995,000.00
# 6856                        Threema    2,990,000.00
# 6746     Card Wars - Adventure Time    2,990,000.00
# 7954                    Bloons TD 5    2,990,000.00

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
df_apps_clean.Category.nunique() # number of unique categories
# Out:
# 33

# %%
print(df_apps_clean.Category.value_counts()[:10])
# Out:
# FAMILY             1606
# GAME                910
# TOOLS               718
# PRODUCTIVITY        301
# PERSONALIZATION     298
# LIFESTYLE           297
# FINANCE             296
# MEDICAL             291
# PHOTOGRAPHY         263
# BUSINESS            262
# Name: Category, dtype: int64

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
px.bar(data_frame=df_apps_clean.Category.value_counts()[:10], title='Number of Apps by Category')

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
category_installs = df_apps_clean.groupby('Category').agg({'Installs': pd.Series.sum}) # sum of installs by category and aggregate the results
category_installs.sort_values('Installs', ascending=True, inplace=True)
category_installs.head()
# Out:
#            Installs
# Category
# EVENTS     15949410
# BEAUTY     26916200
# PARENTING  31116110
# MEDICAL    39062676
# COMICS     44931100

# %%
px.bar(x=category_installs.Installs,
       y=category_installs.index, orientation="h",
       title='Total Installs by Category',
       labels={'x': 'Downloads', 'y': 'Categories'}
       )

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">

# %%
category_info = df_apps_clean.groupby('Category').agg({'Installs': pd.Series.sum, 'App': pd.Series.count}) # sum of installs by category and aggregate the results
category_info.shape
# Out:
# (33, 2)

# %% [markdown]
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html) to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
scatter_graph = px.scatter(category_info,
                           x='App', # column name
                           y='Installs',
                           title='Total Installs vs. Number of Apps by Category',
                           labels={'x': 'Downloads', 'y': 'Number of Apps'},
                           size='Installs',
                           size_max=40,
                           color='Installs', # color intensity determined by the "Installs" column values
                           color_continuous_scale=px.colors.sequential.Plasma, # color scale
                           hover_name=category_info.index
                            )
scatter_graph.update_layout(yaxis=dict(type='log'))

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
df_apps_clean['Genres'].nunique()
# Out:
# 114

# %%
df_apps_clean['Genres'].value_counts().tail() # multiple genres beacuse one app can have multiple genres, problem!
# Out:
# Adventure;Brain Games                1
# Travel & Local;Action & Adventure    1
# Art & Design;Pretend Play            1
# Music & Audio;Music & Video          1
# Lifestyle;Pretend Play               1
# Name: Genres, dtype: int64

# %%
# eliminate multiple genres using .stack() method and .str.split() method to split the genres by ';' character and expand the results to a new dataframe
stacked_Genres = df_apps_clean.Genres.str.split(';', expand=True).stack()
stacked_Genres.nunique()
# Out:
# 53

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
colorscaled_bar = px.bar(data_frame=stacked_Genres.value_counts()[:15],
                        title='Number of Apps by Genre',
                        color=stacked_Genres.value_counts()[:15],
                        color_continuous_scale=px.colors.sequential.Agsunset,
                        labels={'index': 'Genres', 'value': 'Number of Apps'},
                        height=600,
                        width=900
)
colorscaled_bar.update_layout(coloraxis_showscale=False)
colorscaled_bar.show()

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_apps_clean.Type.value_counts()
# Out:
# Free    7593
# Paid     589
# Name: Type, dtype: int64

# %%
df_free_vs_paid = df_apps_clean.groupby(['Category', 'Type'], as_index=False).agg({'App': pd.Series.count})
df_free_vs_paid.head()
# Out:
#             Category  Type  App
# 0     ART_AND_DESIGN  Free   58
# 1     ART_AND_DESIGN  Paid    3
# 2  AUTO_AND_VEHICLES  Free   72
# 3  AUTO_AND_VEHICLES  Paid    1
# 4             BEAUTY  Free   42

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
grouped_bar = px.bar(df_free_vs_paid, 
                  x='Category', 
                  y='App', 
                  color='Type',
                  barmode='group', 
                  title='Free vs. Paid Apps by Category')
grouped_bar.update_layout(xaxis={'categoryorder':'total descending'}, yaxis=dict(type='log'), yaxis_title='Number of Apps')
grouped_bar.show()

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
df_apps_clean.head()
# Out:
#                                                 App Category  Rating  Reviews  \
# 21                              KBA-EZ Health Guide  MEDICAL    5.00        4
# 28                                         Ra Ga Ba     GAME    5.00        2
# 47                                          Mu.F.O.     GAME    5.00        2
# 82                                 Brick Breaker BR     GAME    5.00        7
# 99  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00        1
#
#     Size_MBs  Installs  Type  Price Content_Rating   Genres  Total_grossing
# 21     25.00         1  Free   0.00       Everyone  Medical            0.00
# 28     20.00         1  Paid   1.49       Everyone   Arcade            1.49
# 47     16.00         1  Paid   0.99       Everyone   Arcade            0.99
# 82     19.00         5  Free   0.00       Everyone   Arcade            0.00
# 99      4.60         5  Free   0.00       Everyone  Medical            0.00

# %%
boxed_chart = px.box(df_apps_clean, 
                     x='Type', 
                     y='Installs', 
                     title='How Many Downloads are Paid Apps Giving Up?', 
                     color='Type',
                     notched=True, 
                     points='all')
boxed_chart.update_layout(yaxis=dict(type='log'),
                          boxmode='group')

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
df_paid_apps = df_apps_clean[df_apps_clean.Type == 'Paid'] # filter the dataframe to only paid apps
df_paid_apps.head()
# Out:
#                                         App   Category  Rating  Reviews  \
# 28                                 Ra Ga Ba       GAME    5.00        2
# 47                                  Mu.F.O.       GAME    5.00        2
# 233  Chess of Blades (BL/Yaoi Game) (No VA)     FAMILY    4.80        4
# 248                            The DG Buddy   BUSINESS    3.70        3
# 291                     AC DC Power Monitor  LIFESTYLE    5.00        1
#
#      Size_MBs  Installs  Type  Price Content_Rating     Genres  Total_grossing
# 28      20.00         1  Paid   1.49       Everyone     Arcade            1.49
# 47      16.00         1  Paid   0.99       Everyone     Arcade            0.99
# 233     23.00        10  Paid  14.99           Teen     Casual          149.90
# 248     11.00        10  Paid   2.49       Everyone   Business           24.90
# 291      1.20        10  Paid   3.04       Everyone  Lifestyle           30.40

# %%
boxed_chart_category = px.box(df_paid_apps, 
                              x='Category', 
                              y='Total_grossing', 
                              title='How Many Downloads are Paid Apps Giving Up?')
boxed_chart_category.update_layout(yaxis=dict(type='log'), 
                                   xaxis={'categoryorder':'min ascending'},
                                   xaxis_tickangle=35,
                                   xaxis_tickfont_size=10,
                                   yaxis_title='Total Grossing (USD)')                                                                      
boxed_chart_category.show()

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
# what is a median price for a paid app?
df_paid_apps.Price.median()
# Out:
# 2.99

# %%
# compare pricing by category by creating another box plot
boxed_chart_category = px.box(df_paid_apps, 
                                x='Category', 
                                y='Price', 
                                title='How Much are Paid Apps?',
                                color='Category',
                                color_discrete_sequence=px.colors.sequential.Plasma)
boxed_chart_category.update_layout(yaxis=dict(type='log'), 
                                      xaxis={'categoryorder':'max descending'},
                                        xaxis_tickangle=35,
                                        xaxis_tickfont_size=10,
                                        yaxis_title='Price (USD)',
                                        showlegend=False)

# %% [markdown]
# In this lesson we looked at how to:
#
# Pull a random sample from a DataFrame using .sample()
#
# How to find duplicate entries with .duplicated() and .drop_duplicates()
#
# How to convert string and object data types into numbers with .to_numeric()
#
# How to use plotly to generate beautiful pie, donut, and bar charts as well as box and scatter plots
